# %%
import pandas as pd
import numpy as np
import pymongo
import sklearn as sk
from matplotlib import pyplot as plt
import plotly as pl
from tqdm.auto import tqdm
from xml.etree import ElementTree
import urllib

# %% [markdown]
# ## Connecting and loading data

# %%
client = pymongo.MongoClient('mongodb+srv://Ben:fk4PECGVaRV5Uv3w@infinity.9hew3.mongodb.net/<dbname>?retryWrites=true&w=majority')

# %%
db = client.UNSD

# %%
col_ebal = db.ebal
col_unfcc = db.unfcc

# %%
df_unfcc = pd.DataFrame(col_unfcc.find()).drop("_id", axis=1)

# %%
df_ebal = pd.DataFrame(col_ebal.find()).drop("_id", axis=1)

# %% [markdown]
# ## Some Visualization

# %% [markdown]
# #### unfcc

# %%
df_unfcc.groupby(["INDICATOR", "TIME_PERIOD"])["value"].sum().unstack(level=0).plot()

# %%
df_unfcc.groupby(["INDICATOR", "TIME_PERIOD"])["value"].sum().unstack(level=0).iloc[:, :6].sum(axis=1)
# Out:
# TIME_PERIOD
# 1990    2.461591e+07
# 1991    2.412896e+07
# 1992    2.337543e+07
# 1993    2.304573e+07
# 1994    2.278372e+07
# 1995    2.293318e+07
# 1996    2.331986e+07
# 1997    2.309882e+07
# 1998    2.299261e+07
# 1999    2.284722e+07
# 2000    2.305330e+07
# 2001    2.306503e+07
# 2002    2.302479e+07
# 2003    2.332814e+07
# 2004    2.350649e+07
# 2005    2.348296e+07
# 2006    2.346623e+07
# 2007    2.356247e+07
# 2008    2.305966e+07
# 2009    2.156681e+07
# 2010    2.218594e+07
# 2011    2.188949e+07
# 2012    2.161183e+07
# 2013    2.152848e+07
# 2014    2.115208e+07
# 2015    2.101488e+07
# 2016    2.086364e+07
# 2017    2.093841e+07
# dtype: float64

# %%
fit = plt.figure(figsize=(20, 15))
df_unfcc.groupby(["REF_AREA", "TIME_PERIOD"])["value"].mean().unstack(level=1).plot()

# %% [markdown]
# #### ebal

# %%
df_ebal.head()
# Out:
#    Unnamed: 0     REF_AREA              COMMODITY         TRANSACTION UNIT  \
# 0           0  Afghanistan  Primary coal and peat  Primary production  HSO
# 1           1  Afghanistan  Primary coal and peat  Primary production  HSO
# 2           2  Afghanistan  Primary coal and peat  Primary production  HSO
# 3           3  Afghanistan  Primary coal and peat  Primary production  HSO
# 4           4  Afghanistan  Primary coal and peat  Primary production  HSO
#
#    TIME_PERIOD   value
# 0         1990  2709.0
# 1         1991  2425.2
# 2         1992   206.4
# 3         1993   180.6
# 4         1994   154.8

# %%
df_ebal.groupby(["COMMODITY", "TRANSACTION"])["value"].mean().unstack(level=1)
# Out:
# TRANSACTION             Agriculture, forestry and fishing  \
# COMMODITY
# Biofuels and waste                            7784.878300
# Coal and peat products                        2567.421169
# Electricity                                  14199.610614
# Heat                                          6254.440133
# Memo: Renewables                              7274.889858
# Natural Gas                                   8036.917756
# Nuclear                                               NaN
# Oil Products                                 37423.886054
# Primary Oil                                    717.922742
# Primary coal and peat                        16874.914500
# Total energy                                 53162.889808
#
# TRANSACTION             Chemical and petrochemical  \
# COMMODITY
# Biofuels and waste                     4156.142515
# Coal and peat products                12440.468845
# Electricity                           44048.858187
# Heat                                  49460.636841
# Memo: Renewables                       2936.733069
# Natural Gas                           78144.997127
# Nuclear                                        NaN
# Oil Products                          48067.021732
# Primary Oil                            4839.690954
# Primary coal and peat                 61077.084983
# Total energy                         171772.371469
#
# TRANSACTION             Commerce and public services  Construction  \
# COMMODITY
# Biofuels and waste                      11441.460871    573.432140
# Coal and peat products                   1857.951591    221.034323
# Electricity                             69219.610349   5184.929414
# Heat                                    26460.055173   6375.378010
# Memo: Renewables                        10524.612308    593.324358
# Natural Gas                            123104.361634   7562.417744
# Nuclear                                          NaN           NaN
# Oil Products                            39085.504982  12005.703743
# Primary Oil                              1218.491000    685.612500
# Primary coal and peat                   11397.793912   7869.234641
# Total energy                           134497.292997  20710.810531
#
# TRANSACTION             Domestic aviation  Domestic navigation  \
# COMMODITY
# Biofuels and waste                    NaN           415.625646
# Coal and peat products                NaN            68.301923
# Electricity                           NaN                  NaN
# Heat                                  NaN                  NaN
# Memo: Renewables                      NaN           415.625646
# Natural Gas                           NaN          1111.386774
# Nuclear                               NaN                  NaN
# Oil Products                 35667.723955         20593.463535
# Primary Oil                           NaN                  NaN
# Primary coal and peat                 NaN          1728.485690
# Total energy                 35667.723955         20631.424609
#
# TRANSACTION             Electricity, Heat and CHP plants  \
# COMMODITY
# Biofuels and waste                         -43994.005268
# Coal and peat products                     -60634.213534
# Electricity                                250656.846315
# Heat                                       171438.255226
# Memo: Renewables                           -54336.533704
# Natural Gas                               -356714.545381
# Nuclear                                   -913519.144649
# Oil Products                               -56076.038461
# Primary Oil                               -103815.947804
# Primary coal and peat                     -950736.692113
# Total energy                              -454093.255290
#
# TRANSACTION             Energy industries own use       Exports  \
# COMMODITY
# Biofuels and waste                  -24412.358302 -3.576860e+03
# Coal and peat products              -26410.488509 -1.710805e+04
# Electricity                         -26483.634274 -2.116485e+04
# Heat                                -23277.279546 -1.496522e+02
# Memo: Renewables                    -25375.433665 -3.572118e+03
# Natural Gas                        -114109.393531 -6.063666e+05
# Nuclear                                       NaN           NaN
# Oil Products                        -84010.347188 -3.121186e+05
# Primary Oil                         -14370.025355 -1.060316e+06
# Primary coal and peat              -105379.517932 -3.272588e+05
# Total energy                       -139595.381063 -1.099718e+06
#
# TRANSACTION             Final Energy Consumption  ...  \
# COMMODITY                                         ...
# Biofuels and waste                  1.738406e+05  ...
# Coal and peat products              9.668421e+04  ...
# Electricity                         2.526952e+05  ...
# Heat                                1.713456e+05  ...
# Memo: Renewables                    1.732971e+05  ...
# Natural Gas                         4.638356e+05  ...
# Nuclear                                      NaN  ...
# Oil Products                        4.962128e+05  ...
# Primary Oil                         2.459801e+04  ...
# Primary coal and peat               2.312917e+05  ...
# Total energy                        1.335336e+06  ...
#
# TRANSACTION             Transformation in electricity plants - main activity producers  \
# COMMODITY
# Biofuels and waste                                          -3.415340e+04
# Coal and peat products                                      -6.039282e+04
# Electricity                                                  3.021283e+05
# Heat                                                        -8.238015e+04
# Memo: Renewables                                            -5.011781e+04
# Natural Gas                                                 -2.585227e+05
# Nuclear                                                     -1.125635e+06
# Oil Products                                                -5.177880e+04
# Primary Oil                                                 -1.166955e+05
# Primary coal and peat                                       -1.097818e+06
# Total energy                                                -4.922733e+05
#
# TRANSACTION             Transformation in gas works  \
# COMMODITY
# Biofuels and waste                      -491.315789
# Coal and peat products                 48967.828501
# Electricity                                     NaN
# Heat                                            NaN
# Memo: Renewables                        -491.315789
# Natural Gas                            -8006.759532
# Nuclear                                         NaN
# Oil Products                           -3721.361632
# Primary Oil                                     NaN
# Primary coal and peat                 -67368.167165
# Total energy                            4885.981374
#
# TRANSACTION             Transformation in heat plants - main activity producers  \
# COMMODITY
# Biofuels and waste                                          -12240.384143
# Coal and peat products                                      -13269.004887
# Electricity                                                  -1769.208161
# Heat                                                        169028.683132
# Memo: Renewables                                             -9697.334648
# Natural Gas                                                -119456.779747
# Nuclear                                                               NaN
# Oil Products                                                -23910.974576
# Primary Oil                                                 -14598.809438
# Primary coal and peat                                      -150674.822520
# Total energy                                                -28639.989248
#
# TRANSACTION             Transformation in liquefaction plants  \
# COMMODITY
# Biofuels and waste                                        NaN
# Coal and peat products                                    NaN
# Electricity                                               NaN
# Heat                                                      NaN
# Memo: Renewables                                          NaN
# Natural Gas                                    -107789.007838
# Nuclear                                                   NaN
# Oil Products                                              NaN
# Primary Oil                                      36287.341608
# Primary coal and peat                          -288735.424427
# Total energy                                    -38433.193487
#
# TRANSACTION             Transformation in natural gas blending plants  \
# COMMODITY
# Biofuels and waste                                        -591.458716
# Coal and peat products                                   -4778.448276
# Electricity                                                       NaN
# Heat                                                              NaN
# Memo: Renewables                                          -591.458716
# Natural Gas                                              28942.156938
# Nuclear                                                           NaN
# Oil Products                                            159071.611262
# Primary Oil                                            -156749.254492
# Primary coal and peat                                             NaN
# Total energy                                              5130.609757
#
# TRANSACTION             Transformation in oil refineries      Transport  \
# COMMODITY
# Biofuels and waste                                   NaN   43341.431599
# Coal and peat products                               NaN     396.268167
# Electricity                                          NaN   12750.818739
# Heat                                                 NaN    6237.411455
# Memo: Renewables                                     NaN   43341.431599
# Natural Gas                                -2.245574e+04   57161.076863
# Nuclear                                              NaN            NaN
# Oil Products                                1.362709e+06  335540.822788
# Primary Oil                                -1.376645e+06    1529.407714
# Primary coal and peat                                NaN   13553.099122
# Total energy                               -1.524582e+04  362071.313496
#
# TRANSACTION             Transport equipment  \
# COMMODITY
# Biofuels and waste               118.014806
# Coal and peat products           819.553268
# Electricity                    13345.287184
# Heat                            4073.481671
# Memo: Renewables                  97.686239
# Natural Gas                    10342.660794
# Nuclear                                 NaN
# Oil Products                    3369.513758
# Primary Oil                       85.537750
# Primary coal and peat           2780.819319
# Total energy                   24393.248380
#
# TRANSACTION             Transport not elsewhere specified  \
# COMMODITY
# Biofuels and waste                             117.095773
# Coal and peat products                         477.917025
# Electricity                                   6471.104630
# Heat                                          6237.411455
# Memo: Renewables                               117.095773
# Natural Gas                                  18151.307687
# Nuclear                                               NaN
# Oil Products                                 11703.772346
# Primary Oil                                   2550.583636
# Primary coal and peat                         3534.287859
# Total energy                                 13636.479345
#
# TRANSACTION             Wood and wood products
# COMMODITY
# Biofuels and waste                 6375.681133
# Coal and peat products              236.320162
# Electricity                        5856.984725
# Heat                               8169.953197
# Memo: Renewables                   6452.438783
# Natural Gas                        2661.025853
# Nuclear                                    NaN
# Oil Products                       4035.457505
# Primary Oil                          95.007623
# Primary coal and peat              1103.521261
# Total energy                      16558.504430
#
# [11 rows x 53 columns]

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %% [markdown]
# #### UNFCC

# %%
df_unfcc
# Out:
#      FREQ            INDICATOR REF_AREA    UNIT  TIME_PERIOD         value
# 0       A  EN_ATM_CO2E_XLULUCF      AUS  Gg_CO2         1990  2.784244e+05
# 1       A  EN_ATM_CO2E_XLULUCF      AUS  Gg_CO2         1991  2.798724e+05
# 2       A  EN_ATM_CO2E_XLULUCF      AUS  Gg_CO2         1992  2.849121e+05
# 3       A  EN_ATM_CO2E_XLULUCF      AUS  Gg_CO2         1993  2.892349e+05
# 4       A  EN_ATM_CO2E_XLULUCF      AUS  Gg_CO2         1994  2.940146e+05
# ...   ...                  ...      ...     ...          ...           ...
# 8020    A  EN_CLC_GHGE_XLULUCF      USA  Gg_CO2         2013  6.710218e+06
# 8021    A  EN_CLC_GHGE_XLULUCF      USA  Gg_CO2         2014  6.759996e+06
# 8022    A  EN_CLC_GHGE_XLULUCF      USA  Gg_CO2         2015  6.623775e+06
# 8023    A  EN_CLC_GHGE_XLULUCF      USA  Gg_CO2         2016  6.492267e+06
# 8024    A  EN_CLC_GHGE_XLULUCF      USA  Gg_CO2         2017  6.456718e+06
#
# [8025 rows x 6 columns]

# %%
values = df_unfcc.groupby(["TIME_PERIOD", "REF_AREA"])["value"].sum().unstack(level=0)

# %%
values
# Out:
# TIME_PERIOD          1990          1991          1992          1993  \
# REF_AREA
# AUS          8.406306e+05  8.427629e+05  8.514050e+05  8.524645e+05
# AUT          1.573407e+05  1.646986e+05  1.515009e+05  1.518646e+05
# BEL          2.931732e+05  2.986471e+05  2.978408e+05  2.957808e+05
# BGR          2.036982e+05  1.668341e+05  1.555713e+05  1.535177e+05
# BLR          2.785486e+05  2.617552e+05  2.420003e+05  2.146625e+05
# CAN          1.204369e+06  1.186804e+06  1.220881e+06  1.224529e+06
# CHE          1.065032e+05  1.102331e+05  1.097587e+05  1.046491e+05
# CYP          1.133771e+04  1.236629e+04  1.323235e+04  1.379713e+04
# CZE          3.947854e+05  3.583637e+05  3.453739e+05  3.300364e+05
# DEU          2.495916e+06  2.402246e+06  2.302006e+06  2.284133e+06
# DNK          1.410309e+05  1.622915e+05  1.503309e+05  1.547407e+05
# ESP          5.769850e+05  5.924081e+05  6.119522e+05  5.914752e+05
# EST          8.086302e+04  7.456731e+04  5.458426e+04  4.270148e+04
# EU1          1.129297e+07  1.110447e+07  1.075405e+07  1.055748e+07
# UKR          7.205338e+05  6.335421e+05  6.702314e+05  6.412516e+05
# USA          1.350903e+07  1.323526e+07  1.297105e+07  1.289881e+07
#
# [43 rows x 28 columns]

# %%
sorted([values.sum(axis=1).reset_index().values[i, :] for i in range(values.shape[0])], key=lambda x:-x[1])[:10]
# Out:
# [array(['USA', 384140950.0065113], dtype=object),
#  array(['EU1', 281443132.49281037], dtype=object),
#  array(['RUS', 119623741.2249493], dtype=object),
#  array(['JPN', 75191469.25156285], dtype=object),
#  array(['DEU', 57495512.690616], dtype=object),
#  array(['CAN', 38841393.50655234], dtype=object),
#  array(['GBR', 37694077.48344614], dtype=object),
#  array(['FRA', 29822242.489216022], dtype=object),
#  array(['ITA', 28933228.78811453], dtype=object),
#  array(['AUS', 27698447.56692304], dtype=object)]

# %%
window = 6
model = LinearRegression()
X = []
y = []
for i in range(values.shape[1] - window - 1):
    X.append(values.values[:, i:(i + window)])
    y.append(values.values[:, i + window])
train_X = np.concatenate(X[:-1])
train_y = np.concatenate(y[:-1])

# %%
test_X = X[-1]
test_y = y[-1]

# %%
X.shape, y.shape
# Out:
# ((860, 6), (860,))

# %%
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(model.predict(train_X), train_y)
plt.title("Training Data")
# Out:
# Text(0.5, 1.0, 'Training Data')

# %%
plt.scatter(model.predict(test_X), test_y)
plt.title("Testing Data")
# Out:
# Text(0.5, 1.0, 'Testing Data')

# %%
values.loc[:, "preds_last"] = model.predict(test_X).flatten()

# %%
for i in values.index:
    plt.plot(values.columns[:-2], values.loc[i][:-2], marker='x')
    plt.plot(values.columns[-4:-2], values.loc[i, [2016, "preds_last"]].values, marker='x', color='r')
    break

# %%
df_unfcc.shape
# Out:
# (8025, 7)

# %%
model.predict(test_X).shape
# Out:
# (43,)

# %% [markdown]
# #### ebal

# %%
df_ebal.head()
# Out:
#    Unnamed: 0     REF_AREA              COMMODITY         TRANSACTION UNIT  \
# 0           0  Afghanistan  Primary coal and peat  Primary production  HSO
# 1           1  Afghanistan  Primary coal and peat  Primary production  HSO
# 2           2  Afghanistan  Primary coal and peat  Primary production  HSO
# 3           3  Afghanistan  Primary coal and peat  Primary production  HSO
# 4           4  Afghanistan  Primary coal and peat  Primary production  HSO
#
#    TIME_PERIOD   value
# 0         1990  2709.0
# 1         1991  2425.2
# 2         1992   206.4
# 3         1993   180.6
# 4         1994   154.8

# %%
data_ebal = df_ebal.loc[:, ["REF_AREA", "COMMODITY", "TRANSACTION", "TIME_PERIOD", "value"]]

# %%
top_ten_trc = [entry[0] for entry in sorted([(ind, val) for ind, val in data_ebal.groupby("TRANSACTION")["value"].sum().items()], key=lambda x:-abs(x[1]))[:10]]

# %%
top_ten_trc
# Out:
# ['Primary production',
#  'Total energy supply',
#  'Final consumption',
#  'Final Energy Consumption',
#  'Exports',
#  'Imports',
#  'Other Consumption',
#  'Transformation',
#  'Manufacturing, construction and non-fuel mining industries',
#  'Electricity, Heat and CHP plants']

# %%
df_ebal.COMMODITY.unique()
# Out:
# array(['Primary coal and peat', 'Coal and peat products', 'Primary Oil',
#        'Oil Products', 'Natural Gas', 'Biofuels and waste', 'Electricity',
#        'Total energy', 'Memo: Renewables', 'Heat', 'Nuclear'],
#       dtype=object)

# %%
top_five_comm = [entry[0] for entry in sorted([(ind, val) for ind, val in data_ebal.groupby("COMMODITY")["value"].sum().items()], key=lambda x:-abs(x[1]))[:6]]

# %%
top_five_comm
# Out:
# ['Total energy',
#  'Oil Products',
#  'Electricity',
#  'Natural Gas',
#  'Memo: Renewables',
#  'Biofuels and waste',
#  'Primary coal and peat',
#  'Heat',
#  'Coal and peat products',
#  'Nuclear']

# %%
data_ebal = data_ebal.query("(COMMODITY in @top_five_comm) and (TRANSACTION in @ top_ten_trc)").reset_index(drop=True)

# %%
data_ebal
# Out:
#            REF_AREA         COMMODITY        TRANSACTION  TIME_PERIOD  \
# 0       Afghanistan      Oil Products            Imports         1990
# 1       Afghanistan      Oil Products            Imports         1991
# 2       Afghanistan      Oil Products            Imports         1992
# 3       Afghanistan      Oil Products            Imports         1993
# 4       Afghanistan      Oil Products            Imports         1994
# ...             ...               ...                ...          ...
# 218811       Zambia  Memo: Renewables  Other Consumption         2013
# 218812       Zambia  Memo: Renewables  Other Consumption         2014
# 218813       Zambia  Memo: Renewables  Other Consumption         2015
# 218814       Zambia  Memo: Renewables  Other Consumption         2016
# 218815       Zambia  Memo: Renewables  Other Consumption         2017
#
#              value
# 0        27763.800
# 1        25864.000
# 2        14547.200
# 3        14027.600
# 4        13418.500
# ...            ...
# 218811  174646.500
# 218812  178963.865
# 218813  191358.500
# 218814  215484.500
# 218815  222003.000
#
# [218816 rows x 5 columns]

# %%
df_ebal.TRANSACTION.unique()
# Out:
# array(['Primary production', 'Imports', 'Exports', 'Total energy supply',
#        'Statistical differences', 'Transformation',
#        'Electricity, Heat and CHP plants',
#        'Transformation in electricity plants - main activity producers',
#        'Transformation in coke ovens', 'Final consumption',
#        'Final Energy Consumption',
#        'Manufacturing, construction and non-fuel mining industries',
#        'Industry consumption not elsewhere specified',
#        'Transformation in briquetting plants',
#        'Transformation in natural gas blending plants',
#        'International aviation bunkers', 'Stock changes', 'Transport',
#        'Road', 'Domestic aviation', 'Other Consumption', 'Households',
#        'Non-energy use', 'Other transformation',
#        'Energy industries own use', 'Losses',
#        'Agriculture, forestry and fishing',
#        'Commerce and public services',
#        'Other consumption not elsewhere specified', 'Iron and steel',
#        'Non-ferrous metals', 'Non-metallic minerals',
#        'Transformation in oil refineries', 'International marine bunkers',
#        'Transformation in heat plants - main activity producers',
#        'Chemical and petrochemical', 'Mining and quarrying',
#        'Food and tobacco', 'Paper, pulp and printing',
#        'Textile and leather', 'Construction', 'Rail',
#        'Domestic navigation', 'Wood and wood products',
#        'Transport not elsewhere specified',
#        'Transformation in blast furnaces',
#        'Transfers and recycled products', 'Pipeline transport',
#        'Transformation in CHP plants - main activity producers',
#        'Transport equipment', 'Machinery',
#        'Transformation in liquefaction plants',
#        'Transformation in gas works'], dtype=object)

# %%
def mse(a, b):
    return np.mean(np.square([i - j for i, j in zip(a, b)])) / max(np.mean(np.square(a)), np.mean(np.square(b)))

# %%
from sklearn.impute import SimpleImputer

# %%
im = SimpleImputer()

# %%
im.fit([[1, 2], [np.nan, 3], [5, 7]])
# Out:
# SimpleImputer()

# %%
a = [[1], [1]]

# %%
im.fit_transform(a)
# Out:
# array([[1.],
#        [1.]])

# %%
a
# Out:
# [[1, nan], [1, nan]]

# %%
def make_models(
    data,
    model_func,
    comms,
    trans,
    window=6,
    imputer=SimpleImputer,
):
    
    ans = {}
    for comm in comms:
        for tran in trans:
            imputer_ele = imputer()
            sub_data = data.query("(COMMODITY == @comm) and (TRANSACTION == @tran)")
            df = sub_data.groupby(["TIME_PERIOD", "REF_AREA"])['value'].sum().unstack(level=0)
#             return df
            model = model_func()
            X = []
            y = []
            if df.shape[1] < 8:
                continue
            for i in range(df.shape[1] - window - 1):
                X.append(df.values[:, i:(i + window)])
                y.append(df.values[:, i + window])
            
            train_X = np.concatenate(X[:-1])
            train_y = np.concatenate(y[:-1])
#             print(train_X.shape, train_y.shape)
            train_X = imputer_ele.fit_transform(train_X)
            test_X = imputer_ele.transform(X[-1])
#             print(train_X.shape, train_y.shape)
            train_y = imputer_ele.fit_transform(train_y.reshape(-1, 1))
            test_y = imputer_ele.transform(y[-1].reshape(-1, 1))
#             print(train_X.shape, train_y.shape)
            model.fit(train_X, train_y)
            loss = mse(model.predict(test_X), test_y)
            
            ans[(comm, tran)] = (model, loss)
    return ans

# %%
len(df_ebal.REF_AREA.unique())
# Out:
# 214

# %%
make_models(data_ebal, LinearRegression, top_five_comm, top_ten_trc)
# Out:
# {('Total energy', 'Primary production'): (LinearRegression(),
#   0.003901294037188426),
#  ('Total energy', 'Total energy supply'): (LinearRegression(),
#   0.0002664820548133845),
#  ('Total energy', 'Final consumption'): (LinearRegression(),
#   0.0005806130509406222),
#  ('Total energy', 'Final Energy Consumption'): (LinearRegression(),
#   0.0008383558766060309),
#  ('Total energy', 'Exports'): (LinearRegression(), 0.007286713395986073),
#  ('Total energy', 'Imports'): (LinearRegression(), 0.006597533252547447),
#  ('Total energy', 'Other Consumption'): (LinearRegression(),
#   0.0017850515449700929),
#  ('Total energy', 'Transformation'): (LinearRegression(),
#   0.0006933646131190261),
#  ('Total energy',
#   'Manufacturing, construction and non-fuel mining industries'): (LinearRegression(),
#   0.004371152171163456),
#  ('Total energy', 'Electricity, Heat and CHP plants'): (LinearRegression(),
#   0.0021520969812000306),
#  ('Oil Products', 'Total energy supply'): (LinearRegression(),
#   0.029491736035774565),
#  ('Oil Products', 'Final consumption'): (LinearRegression(),
#   0.0011585642942892743),
#  ('Oil Products', 'Final Energy Consumption'): (LinearRegression(),
#   0.0006277839749639205),
#  ('Oil Products', 'Exports'): (LinearRegression(), 0.011345741906370482),
#  ('Oil Products', 'Imports'): (LinearRegression(), 0.005194554376189674),
#  ('Oil Products', 'Other Consumption'): (LinearRegression(),
#   0.012780186055973869),
#  ('Oil Products', 'Transformation'): (LinearRegression(),
#   0.0009016212847974613),
#  ('Oil Products',
#   'Manufacturing, construction and non-fuel mining industries'): (LinearRegression(),
#   0.015124417666441793),
#  ('Oil Products', 'Electricity, Heat and CHP plants'): (LinearRegression(),
#   0.03060602505381491),
#  ('Electricity', 'Primary production'): (LinearRegression(),
#   0.0018701284149138231),
#  ('Electricity', 'Total energy supply'): (LinearRegression(),
#   0.0022650834270090884),
#  ('Electricity', 'Final consumption'): (LinearRegression(),
#   0.00010026416843034172),
#  ('Electricity', 'Final Energy Consumption'): (LinearRegression(),
#   0.00010026416843034172),
#  ('Electricity', 'Exports'): (LinearRegression(), 0.022265751779181196),
#  ('Electricity', 'Imports'): (LinearRegression(), 0.031717581947832404),
#  ('Electricity', 'Other Consumption'): (LinearRegression(),
#   0.0005283744729017816),
#  ('Electricity', 'Transformation'): (LinearRegression(), 0.000570742911672647),
#  ('Electricity',
#   'Manufacturing, construction and non-fuel mining industries'): (LinearRegression(),
#   0.000771685472191381),
#  ('Electricity', 'Electricity, Heat and CHP plants'): (LinearRegression(),
#   0.000570742911672647),
#  ('Natural Gas', 'Primary production'): (LinearRegression(),
#   0.0011147110928983316),
#  ('Natural Gas', 'Total energy supply'): (LinearRegression(),
#   0.0033156500629164007),
#  ('Natural Gas', 'Final consumption'): (LinearRegression(),
#   0.00401278110852251),
#  ('Natural Gas', 'Final Energy Consumption'): (LinearRegression(),
#   0.004257087020055924),
#  ('Natural Gas', 'Exports'): (LinearRegression(), 0.023469361715282366),
#  ('Natural Gas', 'Imports'): (LinearRegression(), 0.026501325467299258),
#  ('Natural Gas', 'Other Consumption'): (LinearRegression(),
#   0.003923442569028868),
#  ('Natural Gas', 'Transformation'): (LinearRegression(), 0.005217983806168217),
#  ('Natural Gas',
#   'Manufacturing, construction and non-fuel mining industries'): (LinearRegression(),
#   0.009537699179129786),
#  ('Natural Gas', 'Electricity, Heat and CHP plants'): (LinearRegression(),
#   0.005095424787528794),
#  ('Memo: Renewables', 'Primary production'): (LinearRegression(),
#   0.0008443087866644714),
#  ('Memo: Renewables', 'Total energy supply'): (LinearRegression(),
#   0.000632587292198666),
#  ('Memo: Renewables', 'Final consumption'): (LinearRegression(),
#   0.0014746013128165204),
#  ('Memo: Renewables', 'Final Energy Consumption'): (LinearRegression(),
#   0.0014746013128165204),
#  ('Memo: Renewables', 'Exports'): (LinearRegression(), 0.09215236939569654),
#  ('Memo: Renewables', 'Imports'): (LinearRegression(), 0.11035989642108189),
#  ('Memo: Renewables', 'Other Consumption'): (LinearRegression(),
#   0.01098513330819708),
#  ('Memo: Renewables', 'Transformation'): (LinearRegression(),
#   0.04044892836085586),
#  ('Memo: Renewables',
#   'Manufacturing, construction and non-fuel mining industries'): (LinearRegression(),
#   0.0705375655783002),
#  ('Memo: Renewables', 'Electricity, Heat and CHP plants'): (LinearRegression(),
#   0.041945723360287505)}

# %%
def make_model(model_func):
    
    all_model = model_func()
    df = df.groupby("TIME_PERIOD")["value"].mean()

# %% [markdown]
# ## Improved Visualization
