# %% [markdown]
# ## Getting the imports

# %%
import pandas as pd
import pandasdmx as sdmx
import pymongo
import json
import urllib
from xml.etree import ElementTree

unsd = sdmx.Request('UNSD') #Get the UNSD DataSource
unsd_flow = unsd.dataflow()
unsd_str = unsd.datastructure()

# %% [markdown]
# ## Inspect the different dataset labels

# %%
#All the dataflows
dataflows = sdmx.to_pandas(unsd_flow.dataflow) #All dataflows
dataflows
# Out:
# DF_UNDATA_COUNTRYDATA             SDMX-CountryData
# DF_UNDATA_SEEA_SUPPLY             SEEA SUPPLY DATA
# DF_UNDATA_SEEA_USE                   SEEA USE DATA
# DF_UNData_EnergyBalance    Energy Balance DataFlow
# DF_UNData_UNFCC                    SDMX_GHG_UNDATA
# dtype: object

# %%
# Extract the UNFCC and Energy Balance dataset
unfcc_msg = unsd.dataflow('DF_UNData_UNFCC')
ebal_msg = unsd.dataflow('DF_UNData_EnergyBalance')
unfcc_msg, ebal_msg
# Out:
# (<pandasdmx.StructureMessage>
#    <Header>
#      id: 'IDREF461'
#      prepared: '2020-11-28T17:01:07.155652+01:00'
#      receiver: <Agency Unknown>
#      sender: <Agency Unknown>
#      source:
#      test: False
#    response: <Response [200]>
#    Categorisation (1): DF_UNData_UNFCC@ESTAT@10@UNdata_Categories@10@ENVI
#    CategoryScheme (1): UNdata_Categories
#    Codelist (4): CL_FREQ CL_INDICATOR CL_REF_AREA CL_UNIT
#    ConceptScheme (1): CS_UNDATA
#    DataflowDefinition (1): DF_UNData_UNFCC
#    DataStructureDefinition (1): DSD_GHG_UNDATA,
#  <pandasdmx.StructureMessage>
#    <Header>
#      id: 'IDREF462'
#      prepared: '2020-11-28T17:01:07.673640+01:00'
#      receiver: <Agency Unknown>
#      sender: <Agency Unknown>
#      source:
#      test: False
#    response: <Response [200]>
#    Categorisation (1): 0EA2206C2115061F7C2EF4F6D9E58EA07F002A5A
#    CategoryScheme (1): UNdata_Categories
#    Codelist (6): CL_AREA CL_COMMODITY_ENERGY_BALANCE_UNDATA CL_ESTIMATE ...
#    ConceptScheme (1): CS_ENERGY_BALANCE_UNDATA
#    DataflowDefinition (1): DF_UNData_EnergyBalance
#    DataStructureDefinition (1): DSD_ENERGY_BALANCE_UNDATA)

# %%
#Get the DataStructures
dsd_unfcc = unfcc_msg.structure.DSD_GHG_UNDATA
dsd_ebal = ebal_msg.structure.DSD_ENERGY_BALANCE_UNDATA

# %%
#Show the different codelists
dsd_ebal.dimensions.components, dsd_unfcc.dimensions.components

# %% [markdown]
# ## Getting the Data

# %%
resp_unfcc = unsd.data('DF_UNData_UNFCC')
resp_ebal = unsd.data('DF_UNData_EnergyBalance')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-44f8829c255b> in <module>
#       1 resp_unfcc = unsd.data('DF_UNData_UNFCC')
# ----> 2 resp_ebal = unsd.data('DF_UNData_EnergyBalance')
#
# D:\Anaconda3\lib\site-packages\pandasdmx\api.py in get(self, resource_type, resource_id, tofile, use_cache, dry_run, **kwargs)
#     417
#     418         try:
# --> 419             response = self.session.send(req)
#     420             response.raise_for_status()
#     421         except requests.exceptions.ConnectionError as e:
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# D:\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# D:\Anaconda3\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# D:\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# D:\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     667                 if self.chunk_left == 0:
#     668                     break
# --> 669                 chunk = self._handle_chunk(amt)
#     670                 decoded = self._decode(chunk, decode_content=decode_content,
#     671                                        flush_decoder=False)
#
# D:\Anaconda3\lib\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#     613             self.chunk_left = None
#     614         elif amt < self.chunk_left:
# --> 615             value = self._fp._safe_read(amt)
#     616             self.chunk_left = self.chunk_left - amt
#     617             returned_chunk = value
#
# D:\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     608         s = []
#     609         while amt > 0:
# --> 610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
#     612                 raise IncompleteRead(b''.join(s), amt)
#
# D:\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# D:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# D:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
df_ebal = resp_ebal.to_pandas()
df_unfcc = resp_unfcc.to_pandas()

# %%
df_ebal.head(), df_unfcc.head()

# %%
df_unfcc.reset_index().to_csv('data_unfcc.csv',index=False)
df_ebal.reset_index().to_csv('data_ebal.csv',index=False)

# %% [markdown]
# ## Creating MongoDB server

# %%
client = pymongo.MongoClient('mongodb+srv://sayan:infinity@infinity.9hew3.mongodb.net/<dbname>?retryWrites=true&w=majority')
# client = pymongo.MongoClient('localhost:27017')

# %%
# client = pymongo.MongoClient('mongodb+srv://infinity.9hew3.mongodb.net/<dbname>')

# %%
db = client.UNSD

# %%
client.UNSD
# Out:
# Database(MongoClient(host=['infinity-shard-00-00.9hew3.mongodb.net:27017', 'infinity-shard-00-02.9hew3.mongodb.net:27017', 'infinity-shard-00-01.9hew3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-gqwf22-shard-0', ssl=True), 'UNSD')

# %%
col_ebal = db.ebal
col_unfcc = db.unfcc

# %%
data_json_unfcc = pd.DataFrame(col_unfcc.find()).drop("_id", axis=1)

# %%
data_json_ebal = pd.DataFrame(col_ebal.find()).drop("_id", axis=1)

# %%
data_json_ebal = data_json_ebal.drop("Unnamed: 0", axis=1)

# %%
import country_converter as coco

# %%
coco_dict = {}
for i in data_json_ebal["REF_AREA"].unique():
#     if i not in coco_dict:
    coco_dict[i] = coco.convert(i, to='iso3')
# Out:
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for France-Monaco
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Italy-San Marino
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein
# More then one regular expression match for Switzerland-Liechtenstein

# %%
coco_dict["France-Monaco"] = coco.convert("France", to='iso3')

# %%
coco_dict["Italy-San Marino"] = coco.convert("Italy", to='iso3')

# %%
coco_dict["Switzerland-Liechtenstein"] = coco.convert("Switzerland", to='iso3')

# %%
coco_dict.values()
# Out:
# dict_values(['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ATG', 'AZE', 'ARG', 'AUS', 'AUT', 'BHS', 'BHR', 'BGD', 'ARM', 'BRB', 'BEL', 'BMU', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA', 'BLZ', 'SLB', 'VGB', 'BRN', 'BGR', 'MMR', 'BDI', 'BLR', 'KHM', 'CMR', 'CAN', 'CPV', 'CYM', 'CAF', 'LKA', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COG', 'COD', 'COK', 'CRI', 'HRV', 'CUB', 'CYP', 'CZE', 'BEN', 'DNK', 'DMA', 'DOM', 'ECU', 'SLV', 'GNQ', 'ETH', 'ERI', 'EST', 'FRO', 'FLK', 'FJI', 'FIN', 'FRA', 'PYF', 'DJI', 'GAB', 'GEO', 'GMB', 'PSE', 'DEU', 'GHA', 'GIB', 'KIR', 'GRC', 'GRL', 'GRD', 'GTM', 'GIN', 'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL', 'ISR', 'ITA', 'CIV', 'JAM', 'JPN', 'KAZ', 'JOR', 'KEN', 'PRK', 'KOR', 'XKX', 'KWT', 'KGZ', 'LAO', 'LBN', 'LSO', 'LVA', 'LBR', 'LBY', 'LTU', 'LUX', 'MAC', 'MDG', 'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MRT', 'MUS', 'MEX', 'MNG', 'MDA', 'MNE', 'MSR', 'MAR', 'MOZ', 'OMN', 'NAM', 'NRU', 'NPL', 'NLD', 'CUW', 'ABW', 'SXM', 'BES', 'NCL', 'VUT', 'NZL', 'NIC', 'NER', 'NGA', 'NIU', 'NOR', 'FSM', 'PLW', 'PAK', 'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'POL', 'PRT', 'GNB', 'TLS', 'QAT', 'ROU', 'RUS', 'RWA', 'SHN', 'KNA', 'AIA', 'LCA', 'SPM', 'VCT', 'STP', 'SAU', 'SEN', 'SRB', 'SYC', 'SLE', 'SGP', 'SVK', 'VNM', 'SVN', 'SOM', 'ZAF', 'ZWE', 'ESP', 'SSD', 'SDN', 'SUR', 'SWZ', 'SWE', 'CHE', 'SYR', 'TJK', 'THA', 'TGO', 'TON', 'TTO', 'ARE', 'TUN', 'TUR', 'TKM', 'TCA', 'TUV', 'UGA', 'UKR', 'MKD', 'EGY', 'GBR', 'TZA', 'USA', 'BFA', 'URY', 'UZB', 'VEN', 'WLF', 'WSM', 'YEM', 'ZMB'])

# %%
data_json_ebal["REF_AREA"] = [coco_dict[i] for i in data_json_ebal["REF_AREA"]]

# %%
#data_json_ebal["REF_AREA"] = 
coco.convert(names=data_json_ebal["REF_AREA"].values, to='iso3')
# Out:
# More then one regular expression match for ['Afghanistan' 'Afghanistan' 'Afghanistan' ... 'Zambia' 'Zambia' 'Zambia']
# More then one regular expression match for ['Afghanistan' 'Afghanistan' 'Afghanistan' ... 'Zambia' 'Zambia' 'Zambia']
# ['AFG', 'ZMB']

# %%
df_ebal = pd.read_csv('old_data_ebal.csv')
df_unfcc = pd.read_csv('old_data_unfcc.csv')
data_json_unfcc = json.loads(df_unfcc.to_json(orient='records'))
data_json_ebal = json.loads(df_ebal.to_json(orient='records'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5385304d3338> in <module>
# ----> 1 df_ebal = pd.read_csv('data_ebal.csv')
#       2 df_unfcc = pd.read_csv('data_unfcc.csv')
#       3 data_json_unfcc = json.loads(df_unfcc.to_json(orient='records'))
#       4 data_json_ebal = json.loads(df_ebal.to_json(orient='records'))
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data_ebal.csv does not exist: 'data_ebal.csv'

# %%
col_ebal.insert_many(data_json_ebal)
col_unfcc.insert_many(data_json_unfcc)

# %% [markdown]
# ## Maintaining Server

# %%
from tqdm import tqdm

old_df = pd.read_csv('old_data_ebal.csv')
new_df = pd.read_csv('data_ebal.csv')

update_df = new_df[~new_df.apply(tuple,1).isin(old_df.apply(tuple,1))]

db = client.get_database('UNSD')
col_ebal = db.get_collection('ebal')
update_count = 0

for record in tqdm(update_df.to_dict('records')):
    result = col_unfcc.replace_one(filter=record, # locate the document if exists
                                    replacement=record,# latest document   
                                    upsert=True)          # update if exists, insert if not
    if result.upserted_id is not None:
        update_count += 1

# %%
df_ebal = pd.read_csv("../data-1050-infinity_backup/ebal.csv")

# %%
col_ebal.delete_many({})

# %%
col_ebal.insert_many(json.loads(df_json_ebal.to_json(orient='records')))

# %% [markdown]
# ### Decoding codes

# %%
f = urllib.request.urlopen("https://data.un.org/ws/rest/codelist/unsd/CL_AREA/").read()
root = ElementTree.fromstring(f)
area_dict = {}
for ele in root[1][0][0][2:]:
    try:
        area_dict[ele.attrib["id"]] = ele[0].text
    except AttributeError:
        continue

# %%
f = urllib.request.urlopen("https://data.un.org/ws/rest/codelist/unsd/CL_COMMODITY_ENERGY_BALANCE_UNDATA/").read()
root = ElementTree.fromstring(f)
comm_dict = {}
for ele in root[1][0][0][1:]:
    try:
        comm_dict[ele.attrib["id"]] = ele[0].text
    except AttributeError:
        continue

# %%
f = urllib.request.urlopen("https://data.un.org/ws/rest/codelist/unsd/CL_TRANS_ENERGY_BALANCE_UNDATA/").read()
root = ElementTree.fromstring(f)
trans_dict = {}
for ele in root[1][0][0][1:]:
    try:
        trans_dict[ele.attrib["id"]] = ele[0].text
    except AttributeError:
        continue

# %%
df_ebal["COMMODITY"] = [comm_dict[i] for i in df_ebal["COMMODITY"].values]

# %%
df_ebal["TRANSACTION"] = [trans_dict[i] for i in df_ebal["TRANSACTION"].values]

# %%
df_ebal["REF_AREA"] = [area_dict["{:03d}".format(i)] for i in df_ebal["REF_AREA"].values]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-dee7b5aa63a8> in <module>
# ----> 1 df_ebal["REF_AREA"] = [area_dict["{:03d}".format(i)] for i in df_ebal["REF_AREA"].values]
#
# NameError: name 'df_ebal' is not defined

# %%
f = urllib.request.urlopen("https://data.un.org/ws/rest/codelist/unsd/CL_REF_AREA/").read()
root = ElementTree.fromstring(f)
unfcc_area_dict = {}
for ele in root[1][0][0][1:]:
    try:
        unfcc_area_dict[ele.attrib["id"]] = ele[0].text
    except AttributeError:
        continue

# %%
[i in area_dict.values() for i in unfcc_area_dict.values()]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False]

# %%
unfcc_area_dict
# Out:
# {'AUS': 'Australia',
#  'AUT': 'Austria',
#  'BLR': 'Belarus',
#  'BEL': 'Belgium',
#  'BGR': 'Bulgaria',
#  'CAN': 'Canada',
#  'HRV': 'Croatia',
#  'CYP': 'Cyprus',
#  'CZE': 'Czech Republic',
#  'DNK': 'Denmark',
#  'EST': 'Estonia',
#  'FIN': 'Finland',
#  'FRA': 'France',
#  'DEU': 'Germany',
#  'GRC': 'Greece',
#  'HUN': 'Hungary',
#  'ISL': 'Iceland',
#  'IRL': 'Ireland',
#  'ITA': 'Italy',
#  'JPN': 'Japan',
#  'LVA': 'Latvia',
#  'LIE': 'Liechtenstein',
#  'LTU': 'Lithuania',
#  'LUX': 'Luxembourg',
#  'MLT': 'Malta',
#  'MCO': 'Monaco',
#  'NLD': 'Netherlands',
#  'NZL': 'New Zealand',
#  'NOR': 'Norway',
#  'POL': 'Poland',
#  'PRT': 'Portugal',
#  'ROU': 'Romania',
#  'RUS': 'Russian Federation',
#  'SVK': 'Slovakia',
#  'SVN': 'Slovenia',
#  'ESP': 'Spain',
#  'SWE': 'Sweden',
#  'CHE': 'Switzerland',
#  'TUR': 'Turkey',
#  'UKR': 'Ukraine',
#  'GBR': 'United Kingdom of Great Britain and Northern Ireland',
#  'USA': 'United States of America',
#  'EU1': 'European Union'}

# %%
area_dict
# Out:
# {'000': 'Total',
#  '001': 'World',
#  '002': 'Africa',
#  '006': 'Asia [former]',
#  '007': 'Europe [former]',
#  '009': 'Oceania',
#  '010': 'Antarctica',
#  '015': 'Northern Africa',
#  '012': 'Algeria',
#  '019': 'Americas',
#  '003': 'North America',
#  '021': 'Northern America',
#  '025': 'South America (Tropical)',
#  '026': 'South America (Temperate)',
#  '027': 'Antarctica, others',
#  '033': 'Southern Asia [former]',
#  '037': 'Western Asia [former]',
#  '038': 'Western Europe [former]',
#  '041': 'Eastern Europe [former]',
#  '042': 'Northern Europe [former]',
#  '043': 'Europe (exc. Transition Economies)',
#  '045': 'Melanesia [former]',
#  '046': 'Micronesia-Polynesia [former]',
#  '047': 'Micronesia [former]',
#  '049': 'Polynesia [former]',
#  '053': 'Australia and New Zealand',
#  '036': 'Australia',
#  '054': 'Melanesia',
#  '055': 'Micronesia-Polynesia',
#  '057': 'Micronesia',
#  '059': 'Benelux Economic Union',
#  '060': 'Bermuda',
#  '061': 'Polynesia',
#  '016': 'American Samoa',
#  '063': 'Andean Common Market (ANCOM)',
#  '065': 'ASEAN Free Trade Area (AFTA)',
#  '066': 'Asia-Pacific Economic Cooperation (APEC)',
#  '067': 'European Economic Area (EEA)',
#  '069': 'Southern Common Market (MERCOSUR)',
#  '071': 'North American Free Trade Agreement (NAFTA)',
#  '073': 'Association of Southeast Asian Nations (ASEAN)',
#  '080': 'British Antarctic Territory [former]',
#  '081': 'Antarctic Fisheries',
#  '090': 'Solomon Islands',
#  '095': 'Latin American Integration Association (LAIA)',
#  '097': 'European Union (EU)',
#  '098': 'Euro Area',
#  '119': 'The Lome Convention',
#  '124': 'Canada',
#  '127': 'Southern Asia (exc. India)',
#  '130': 'Caribbean Community and Common Market (CARICOM)',
#  '131': 'Organization of Eastern Caribbean States (OECS)',
#  '133': 'Caroline Islands [former]',
#  '134': 'Caucasus',
#  '135': 'Caucasus and Central Asia',
#  '142': 'Asia',
#  '030': 'Eastern Asia',
#  '034': 'Southern Asia',
#  '004': 'Afghanistan',
#  '035': 'South-eastern Asia',
#  '050': 'Bangladesh',
#  '062': 'South-central Asia',
#  '064': 'Bhutan',
#  '096': 'Brunei Darussalam',
#  '104': 'Myanmar',
#  '116': 'Cambodia',
#  '143': 'Central Asia',
#  '144': 'Sri Lanka',
#  '145': 'Western Asia',
#  '031': 'Azerbaijan',
#  '048': 'Bahrain',
#  '051': 'Armenia',
#  '147': 'Developed economies - Asia and Oceania',
#  '150': 'Europe',
#  '039': 'Southern Europe',
#  '008': 'Albania',
#  '020': 'Andorra',
#  '022': 'Andorra (France)',
#  '023': 'Andorra (Spain)',
#  '070': 'Bosnia and Herzegovina',
#  '151': 'Eastern Europe',
#  '100': 'Bulgaria',
#  '112': 'Belarus',
#  '154': 'Northern Europe',
#  '058': 'Belgium-Luxembourg',
#  '155': 'Western Europe',
#  '040': 'Austria',
#  '056': 'Belgium',
#  '156': 'China',
#  '157': 'China (inc. Taiwan province)',
#  '158': 'Taiwan Province of China',
#  '160': 'South-Eastern Europe',
#  '161': 'South-Eastern Europe & CIS',
#  '162': 'Christmas Island',
#  '166': 'Cocos (Keeling) Islands',
#  '171': 'Common Market for Eastern and Southern Africa (COMESA)',
#  '172': 'Commonwealth of Independent States (CIS)',
#  '173': 'CIS in Europe',
#  '176': 'CIS in Asia',
#  '184': 'Cook Islands',
#  '185': 'Cook Islands-Niue',
#  '190': 'Council for Mutual Economic Assistance (CMEA)',
#  '191': 'Croatia',
#  '196': 'Cyprus',
#  '197': 'European Free Trade Association (EFTA)',
#  '198': 'Organisation for Economic Co-operation and Development (OECD)',
#  '199': 'Least Developed Countries (LDCs)',
#  '200': 'Czechoslovakia [former]',
#  '201': 'Most seriously affected countries',
#  '202': 'Sub-Saharan Africa',
#  '011': 'Western Africa',
#  '014': 'Eastern Africa',
#  '017': 'Middle Africa',
#  '018': 'Southern Africa',
#  '024': 'Angola',
#  '072': 'Botswana',
#  '086': 'British Indian Ocean Territory',
#  '108': 'Burundi',
#  '120': 'Cameroon',
#  '121': 'Cameroon (East)',
#  '122': 'Cameroon (West)',
#  '132': 'Cabo Verde',
#  '140': 'Central African Republic',
#  '148': 'Chad',
#  '174': 'Comoros',
#  '175': 'Mayotte',
#  '178': 'Congo',
#  '180': 'Democratic Republic of the Congo',
#  '203': 'Czechia',
#  '204': 'Benin',
#  '208': 'Denmark',
#  '209': 'Denmark-Greenland-Faroe Islands',
#  '216': 'Dronning Maud Land [former]',
#  '217': 'East African Community (EAC)',
#  '219': 'Eastern Africa not elsewhere specified',
#  '220': 'Eastern Asia not elsewhere specified',
#  '221': 'Eastern Europe not elsewhere specified',
#  '223': 'Eastern Asia (exc. Japan and China)',
#  '224': 'European Patent Office (EPO)',
#  '225': 'Eurasian Patent Organization (EAPO)',
#  '226': 'Equatorial Guinea',
#  '227': 'Equatorial Guinea (Rio Muni)',
#  '228': 'Equatorial Guinea (Macias Nguema Biyogo, Bioko)',
#  '230': 'Ethiopia [former]',
#  '231': 'Ethiopia',
#  '232': 'Eritrea',
#  '233': 'Estonia',
#  '234': 'Faroe Islands',
#  '240': 'Food and Agriculture Organization (FAO)',
#  '241': 'International Fund for Agricultural Development (IFAD)',
#  '242': 'Fiji',
#  '246': 'Finland',
#  '248': 'Åland Islands',
#  '250': 'France',
#  '249': 'France, Metropolitan [former]',
#  '251': 'France-Monaco',
#  '252': 'France-Switzerland',
#  '258': 'French Polynesia',
#  '260': 'French Southern Territories',
#  '262': 'Djibouti',
#  '263': 'French Equatorial Africa [former]',
#  '265': 'French Indo-China [former]',
#  '266': 'Gabon',
#  '267': 'French West Africa [former]',
#  '268': 'Georgia',
#  '270': 'Gambia',
#  '272': 'General Agreement on Tariffs and Trade (GATT)',
#  '273': 'Palestine Liberation Organization (PLO)',
#  '275': 'State of Palestine',
#  '274': 'State of Palestine (Gaza Strip)',
#  '276': 'Germany',
#  '278': 'German Democratic Republic [former]',
#  '280': 'Germany, Federal Republic of [former]',
#  '282': 'Germany, East Berlin [former]',
#  '284': 'Germany, West Berlin [former]',
#  '285': 'Northern Europe not elsewhere specified',
#  '286': 'Polynesia not elsewhere specified',
#  '287': 'Sub-Saharan Africa not elsewhere specified',
#  '288': 'Ghana',
#  '289': 'North America not elsewhere specified',
#  '290': 'Northern Africa not elsewhere specified',
#  '291': 'Central Asia not elsewhere specified',
#  '292': 'Gibraltar',
#  '293': 'Northern America not elsewhere specified',
#  '295': 'Economic Community of the Great Lakes Countries (ECGLC)',
#  '296': 'Kiribati',
#  '128': 'Canton and Enderbury Islands [former]',
#  '297': 'Kiribati (exc. Canton and Enderbury Islands) [former]',
#  '300': 'Greece',
#  '304': 'Greenland',
#  '310': 'Group of 77 (G77)',
#  '316': 'Guam',
#  '324': 'Guinea',
#  '325': 'Cooperation Council for the Arab States of the Gulf (GCC)',
#  '334': 'Heard Island and McDonald Islands',
#  '336': 'Holy See',
#  '344': 'China, Hong Kong Special Administrative Region',
#  '348': 'Hungary',
#  '349': 'International Atomic Energy Agency (IAEA)',
#  '350': 'International Bank for Reconstruction and Development (IBRD)',
#  '351': 'International Civil Aviation Organization (ICAO)',
#  '352': 'Iceland',
#  '353': 'International Development Association (IDA)',
#  '354': 'International Finance Corporation (IFC)',
#  '355': 'International Labour Organization (ILO)',
#  '356': 'India',
#  '357': 'International Labour Office (ILO) [former]',
#  '358': 'International Monetary Fund (IMF)',
#  '359': 'International Maritime Organization (IMO)',
#  '360': 'Indonesia',
#  '361': 'Indonesia (exc. East Timor) [former]',
#  '364': 'Iran (Islamic Republic of)',
#  '368': 'Iraq',
#  '372': 'Ireland',
#  '375': 'Organization of the Islamic Conference (OIC)',
#  '376': 'Israel',
#  '378': 'International Trade Centre UNCTAD/GATT (ITC)',
#  '380': 'Italy',
#  '381': 'Italy-San Marino-Holy See',
#  '382': 'Italy-San Marino',
#  '384': 'Côte d’Ivoire',
#  '386': 'International Telecommunication Union (ITU)',
#  '392': 'Japan',
#  '393': 'Japan (exc. Okinawa)',
#  '394': 'Japan (exc. Okinawa, Bonin and Volcano Islands)',
#  '395': 'Central American Common Market (CACM)',
#  '397': 'Central American Corporation for Air Navigation Services (COCESNA)',
#  '398': 'Kazakhstan',
#  '399': 'Organization of the Petroleum Exporting Countries (OPEC)',
#  '400': 'Jordan',
#  '401': 'Jordan (exc. the West Bank) [former]',
#  '402': 'State of Palestine (West Bank)',
#  '404': 'Kenya',
#  '407': "Democratic People's Republic of Korea-Republic of Korea",
#  '408': "Democratic People's Republic of Korea",
#  '410': 'Republic of Korea',
#  '414': 'Kuwait',
#  '415': 'Kuwait (Neutral Zone)',
#  '416': 'Kuwait (exc. Neutral Zone)',
#  '417': 'Kyrgyzstan',
#  '418': "Lao People's Democratic Republic",
#  '419': 'Latin America and the Caribbean',
#  '005': 'South America',
#  '013': 'Central America',
#  '029': 'Caribbean',
#  '028': 'Antigua and Barbuda',
#  '032': 'Argentina',
#  '044': 'Bahamas',
#  '052': 'Barbados',
#  '068': 'Bolivia (Plurinational State of)',
#  '074': 'Bouvet Island',
#  '076': 'Brazil',
#  '084': 'Belize',
#  '092': 'British Virgin Islands',
#  '093': 'British Virgin Islands (Beef Island)',
#  '129': 'Caribbean not elsewhere specified',
#  '136': 'Cayman Islands',
#  '141': 'Central America not elsewhere specified',
#  '152': 'Chile',
#  '153': 'Chile (Easter Island)',
#  '170': 'Colombia',
#  '188': 'Costa Rica',
#  '192': 'Cuba',
#  '212': 'Dominica',
#  '214': 'Dominican Republic',
#  '218': 'Ecuador',
#  '222': 'El Salvador',
#  '238': 'Falkland Islands (Malvinas)',
#  '239': 'South Georgia and the South Sandwich Islands',
#  '253': 'French Antilles [former]',
#  '254': 'French Guiana',
#  '283': 'South America not elsewhere specified',
#  '308': 'Grenada',
#  '312': 'Guadeloupe',
#  '320': 'Guatemala',
#  '328': 'Guyana',
#  '332': 'Haiti',
#  '340': 'Honduras',
#  '388': 'Jamaica',
#  '420': 'Latin America',
#  '422': 'Lebanon',
#  '423': 'British Leeward Islands [former]',
#  '426': 'Lesotho',
#  '428': 'Latvia',
#  '430': 'Liberia',
#  '432': 'Landlocked developing countries (LLDCs)',
#  '434': 'Libya',
#  '438': 'Liechtenstein',
#  '440': 'Lithuania',
#  '442': 'Luxembourg',
#  '446': 'China, Macao Special Administrative Region',
#  '450': 'Madagascar',
#  '452': 'Arab Maghreb Union (AMU)',
#  '454': 'Malawi',
#  '455': 'Federation of Malaya, Sabah, Sarawak and Singapore [former]',
#  '458': 'Malaysia',
#  '459': 'Malaysia (Peninsular)',
#  '460': 'Malaysia (Sabah and Sarawak)',
#  '457': 'Malaysia (Sarawak)',
#  '461': 'Malaysia (Sabah)',
#  '462': 'Maldives',
#  '466': 'Mali',
#  '470': 'Malta',
#  '471': 'Central American Common Market (CACM) not elsewhere specified',
#  '473': 'Latin American Integration Association (LAIA) not elsewhere specified',
#  '474': 'Martinique',
#  '478': 'Mauritania',
#  '476': 'Mauritania (exc. Spanish Sahara) [former]',
#  '480': 'Mauritius',
#  '479': 'Mauritius (Mauritius Island and Rodrigues Island)',
#  '481': 'Mauritius (Mauritius Island)',
#  '482': 'Mauritius (Saint Brandon and Agalega)',
#  '483': 'Mauritius (Rodrigues Island)',
#  '484': 'Mexico',
#  '485': 'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia)',
#  '486': 'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia) not elsewhere specified',
#  '487': 'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia) and Egypt',
#  '489': 'Developing economies - Asia',
#  '490': 'Asia not elsewhere specified',
#  '491': 'Centrally Planned Economies',
#  '492': 'Monaco',
#  '496': 'Mongolia',
#  '497': 'European Union (EU) not elsewhere specified',
#  '498': 'Republic of Moldova',
#  '499': 'Montenegro',
#  '500': 'Montserrat',
#  '501': 'Arab World',
#  '502': 'League of Arab States (LAS)',
#  '504': 'Morocco',
#  '505': 'Morocco (excl. Ifni)',
#  '506': 'Morocco (Ifni)',
#  '508': 'Mozambique',
#  '512': 'Oman',
#  '513': 'Northern America and Europe',
#  '514': 'Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand)',
#  '515': 'Developing regions',
#  '516': 'Namibia',
#  '517': 'Developing economies - Southern Africa',
#  '518': 'Eastern Asia (exc. Japan)',
#  '519': 'Developing economies - Northern America',
#  '520': 'Nauru',
#  '521': 'Near East',
#  '522': 'Near East in Asia',
#  '523': 'Near East in Africa',
#  '524': 'Nepal',
#  '525': 'Developing economies - Americas',
#  '526': 'Developing economies - Other America',
#  '527': 'Oceania not elsewhere specified',
#  '528': 'Netherlands',
#  '530': 'Netherlands Antilles [former, 1986 to 2010]',
#  '531': 'Curaçao',
#  '532': 'Netherlands Antilles [former, pre-1986]',
#  '533': 'Aruba',
#  '534': 'Sint Maarten (Dutch part)',
#  '535': 'Bonaire, Sint Eustatius and Saba',
#  '536': 'Neutral Zone (Saudi Arabia and Iraq) [former]',
#  '537': 'Developing economies - Africa',
#  '538': 'Developing economies - North America',
#  '539': 'Developing economies - South America',
#  '540': 'New Caledonia',
#  '541': 'Developing economies - Asia',
#  '542': 'Developing economies - Europe',
#  '543': 'Oceania (exc. Australia and New Zealand)',
#  '545': 'Developing economies - Total',
#  '529': 'Developing economies not elsewhere specified',
#  '548': 'Vanuatu',
#  '546': 'New Hebrides (French part) [former]',
#  '547': 'New Hebrides (British part) [former]',
#  '550': 'Developed economies - Asia',
#  '551': 'Developed economies - Europe',
#  '552': 'Developed economies - Oceania',
#  '553': 'Developed economies - Total',
#  '554': 'New Zealand',
#  '555': 'New Zealand-Tokelau',
#  '556': 'Antarctica (Ross Dependency)',
#  '557': 'Developed economies not elsewhere specified',
#  '558': 'Nicaragua',
#  '559': 'Centrally Planned Economies - Asia [former]',
#  '560': 'Centrally Planned Economies - Europe [former]',
#  '561': 'Centrally Planned Economies - Total [former]',
#  '562': 'Niger',
#  '563': 'Centrally Planned Economies - Europe and USSR [former]',
#  '564': 'Centrally Planned Economies - Total excluding USSR [former]',
#  '565': 'Centrally Planned Economies not elsewhere specified [former]',
#  '566': 'Nigeria',
#  '568': 'Europe not elsewhere specified',
#  '569': 'Centrally Planned Economies - Europe not elsewhere specified [former]',
#  '570': 'Niue',
#  '571': 'American Oceania',
#  '572': 'Australian Oceania',
#  '573': 'New Zealand Oceania',
#  '574': 'Norfolk Island',
#  '575': 'North West Africa',
#  '577': 'Africa not elsewhere specified',
#  '578': 'Norway',
#  '579': 'Norway-Svalbard and Jan Mayen Islands',
#  '580': 'Northern Mariana Islands',
#  '581': 'United States minor outlying islands',
#  '396': 'Johnston Island [former]',
#  '488': 'Midway Islands [former]',
#  '582': 'Pacific Islands (Trust Territory) [former]',
#  '583': 'Micronesia (Federated States of)',
#  '584': 'Marshall Islands',
#  '585': 'Palau',
#  '586': 'Pakistan',
#  '588': 'East and West Pakistan [former]',
#  '591': 'Panama',
#  '590': 'Panama (exc. Canal Zone) [former]',
#  '592': 'Panama Canal Zone [former]',
#  '593': 'Development Assistance Committee (DAC)',
#  '594': 'Commonwealth of Nations',
#  '595': 'Bangkok Agreement',
#  '597': 'Andean Integration Group',
#  '598': 'Papua New Guinea',
#  '544': 'New Guinea (Trust Territory) [former]',
#  '596': 'Papua [former]',
#  '600': 'Paraguay',
#  '602': 'Patent Cooperation Treaty (PCT)',
#  '604': 'Peru',
#  '608': 'Philippines',
#  '612': 'Pitcairn',
#  '616': 'Poland',
#  '620': 'Portugal',
#  '624': 'Guinea-Bissau',
#  '626': 'Timor-Leste',
#  '627': 'Preferential Trade Area for Eastern and Southern African States (PTA)',
#  '630': 'Puerto Rico',
#  '633': 'FAO Regional Office for Asia and the Pacific (RAPA)',
#  '634': 'Qatar',
#  '636': 'Americas not elsewhere specified',
#  '637': 'Northern and Central America not elsewhere specified',
#  '638': 'Réunion',
#  '642': 'Romania',
#  '643': 'Russian Federation',
#  '644': 'Caribbean Development Bank (CDB)',
#  '645': 'Ruanda-Urundi [former]',
#  '646': 'Rwanda',
#  '647': 'Japan (Okinawa)',
#  '648': 'African Development Bank (AfDB)',
#  '649': 'Asian Development Bank (ADB)',
#  '650': 'Ryukyu Islands [former]',
#  '651': 'Inter-American Development Bank (IDB)',
#  '652': 'Saint Barthélemy',
#  '654': 'Saint Helena',
#  '653': 'Saint Helena (exc. Dependencies)',
#  '655': 'Saint Helena (Ascension)',
#  '656': 'Saint Helena (Tristan da Cunha)',
#  '657': 'Saint Helena, others',
#  '658': 'Saint Kitts-Nevis-Anguilla [former]',
#  '659': 'Saint Kitts and Nevis',
#  '660': 'Anguilla',
#  '662': 'Saint Lucia',
#  '663': 'Saint Martin (French Part)',
#  '666': 'Saint Pierre and Miquelon',
#  '667': 'Bonaire, Sint Eustatius and Saba (Saba)',
#  '668': 'Bonaire, Sint Eustatius and Saba (Sint Eustatius)',
#  '669': 'Bonaire, Sint Eustatius and Saba (Bonaire)',
#  '670': 'Saint Vincent and the Grenadines',
#  '674': 'San Marino',
#  '678': 'Sao Tome and Principe',
#  '680': 'Sark',
#  '682': 'Saudi Arabia',
#  '684': 'Saudi Arabia (Neutral Zone)',
#  '685': 'Denmark-Norway-Sweden',
#  '686': 'Senegal',
#  '688': 'Serbia',
#  '412': 'Kosovo',
#  '689': 'Bank for International Settlements (BIS)',
#  '690': 'Seychelles',
#  '692': 'Economic and Monetary Community of Central Africa (EMCCA)',
#  '472': 'Economic and Monetary Community of Central Africa (EMCCA) not elsewhere specified',
#  '693': 'West African Economic Community (WAEC)',
#  '694': 'Sierra Leone',
#  '695': 'Mano River Union (MRU)',
#  '697': 'European Free Trade Association (EFTA) not elsewhere specified',
#  '698': 'Sikkim [former]',
#  '699': 'India (exc. Sikkim) [former]',
#  '702': 'Singapore',
#  '703': 'Slovakia',
#  '704': 'Viet Nam',
#  '705': 'Slovenia',
#  '706': 'Somalia',
#  '707': 'Somaliland Protectorate, British [former]',
#  '708': 'Italian Trusteeship Territory of Somalia [former]',
#  '709': 'South-eastern Asia not elsewhere specified',
#  '710': 'South Africa',
#  '711': 'Southern African Customs Union (SACU)',
#  '712': 'South Africa-Namibia',
#  '713': 'Southern Africa not elsewhere specified',
#  '714': 'Southern Asia not elsewhere specified',
#  '715': 'Southern Europe not elsewhere specified',
#  '716': 'Zimbabwe',
#  '717': 'Rhodesia-Nyasaland [former]',
#  '718': 'Australia, New Zealand and South Africa',
#  '719': 'Israel, Japan and South Africa',
#  '722': 'Small island developing States (SIDS)',
#  '724': 'Spain',
#  '725': 'Spain (Canary Islands)',
#  '727': 'Ceuta and Melilla (Spanish North Africa)',
#  '728': 'South Sudan',
#  '729': 'Sudan',
#  '730': 'Economic and Social Commission for Asia and the Pacific (ESCAP)',
#  '731': 'Economic and Social Commission for Western Asia (ESCWA)',
#  '732': 'Western Sahara',
#  '477': 'Spanish Sahara (Mauritania part) [former]',
#  '507': 'Spanish Sahara (Moroccan part) [former]',
#  '733': 'Economic Commission for Africa (ECA)',
#  '734': 'Economic Commission for Europe (ECE)',
#  '735': 'Economic Commission for Latin America and the Caribbean (ECLAC)',
#  '736': 'Sudan [former]',
#  '738': 'Sub-Saharan Africa (inc. Sudan)',
#  '740': 'Suriname',
#  '741': 'Latin America and the Caribbean not elsewhere specified',
#  '742': 'Eastern and South-eastern Asia and Oceania',
#  '743': 'Southern Asia (exc. Iran)',
#  '744': 'Svalbard and Jan Mayen Islands',
#  '745': 'Europe and Central Asia',
#  '746': 'Northern Africa (exc. Sudan)',
#  '747': 'Northern Africa and Western Asia',
#  '748': 'Eswatini',
#  '749': 'South Asian Association for Regional Cooperation (SAARC)',
#  '750': 'South Pacific Commission (SPC)',
#  '751': 'South Pacific Bureau for Economic Cooperation (SPEC)',
#  '752': 'Sweden',
#  '753': 'Eastern and South-Eastern Asia',
#  '756': 'Switzerland',
#  '757': 'Switzerland-Liechtenstein',
#  '760': 'Syrian Arab Republic',
#  '762': 'Tajikistan',
#  '764': 'Thailand',
#  '768': 'Togo',
#  '772': 'Tokelau',
#  '776': 'Tonga',
#  '778': 'Transition countries',
#  '780': 'Trinidad and Tobago',
#  '784': 'United Arab Emirates',
#  '785': 'United Arab Emirates (Abu Dhabi)',
#  '786': 'United Arab Emirates (Dubai)',
#  '787': 'United Arab Emirates (Sharjah)',
#  '788': 'Tunisia',
#  '789': 'United Arab Emirates (Ajman)',
#  '790': 'United Arab Emirates (Fujairah)',
#  '791': 'United Arab Emirates (Umm al Qaiwain)',
#  '792': 'Turkey',
#  '793': 'United Arab Emirates (Ras al Khaimah)',
#  '795': 'Turkmenistan',
#  '796': 'Turks and Caicos Islands',
#  '798': 'Tuvalu',
#  '800': 'Uganda',
#  '804': 'Ukraine',
#  '806': 'United Nations Educational, Scientific and Cultural Organization (UNESCO)',
#  '807': 'The former Yugoslav Republic of Macedonia',
#  '808': "United Nations Children's Fund (UNICEF)",
#  '809': 'United Nations Industrial Development Organization (UNIDO)',
#  '810': 'Union of Soviet Socialist Republics [former]',
#  '811': 'Union of Soviet Socialist Republics, others',
#  '813': 'United Nations Development Programme (UNDP)',
#  '814': 'United Nations Conference on Trade and Development (UNCTAD)',
#  '815': 'United Nations Environment Programme (UNEP)',
#  '816': 'United Nations Centre for Human Settlements (UNCHS) (Habitat)',
#  '818': 'Egypt',
#  '783': 'Egypt (Suez Canal)',
#  '819': 'United Nations High Commissioner for Refugees (UNHCR)',
#  '820': 'United Nations Relief and Works Agency for Palestine Refugees in the Near East (UNRWA)',
#  '821': 'United Nations Disaster Relief Organization (UNDRO)',
#  '823': 'United Nations Population Fund (UNFPA)',
#  '826': 'United Kingdom of Great Britain and Northern Ireland',
#  '827': 'United Kingdom of Great Britain and Northern Ireland (England and Wales)',
#  '824': 'United Kingdom of Great Britain and Northern Ireland (England)',
#  '825': 'United Kingdom of Great Britain and Northern Ireland (Wales)',
#  '828': 'United Kingdom of Great Britain and Northern Ireland (Northern Ireland)',
#  '829': 'United Kingdom of Great Britain and Northern Ireland (Scotland)',
#  '830': 'Channel Islands',
#  '831': 'Guernsey',
#  '832': 'Jersey',
#  '833': 'Isle of Man',
#  '834': 'United Republic of Tanzania',
#  '835': 'United Republic of Tanzania (mainland)',
#  '836': 'United Republic of Tanzania (Zanzibar)',
#  '837': 'Bunkers, ship stores',
#  '838': 'Free zones',
#  '839': 'Undisclosed (Special categories)',
#  '840': 'United States of America',
#  '841': 'United States of America-Puerto Rico',
#  '842': 'United States of America-Puerto Rico-United States Virgin Islands',
#  '843': 'United Nations Institute for Training and Research (UNITAR)',
#  '844': 'United Nations University (UNU)',
#  '849': 'United States miscellaneous Pacific Islands [former]',
#  '847': 'United States miscellaneous Pacific Islands [former] (Kingman Reef)',
#  '848': 'United States miscellaneous Pacific Islands [former] (Palmyra Atoll)',
#  '850': 'United States Virgin Islands',
#  '851': 'United States Virgin Islands (Saint Croix)',
#  '852': 'United States Virgin Islands (Saint John)',
#  '853': 'United States Virgin Islands (Saint Thomas)',
#  '854': 'Burkina Faso',
#  '855': 'United States Virgin Islands, others',
#  '857': 'Universal Postal Union (UPU)',
#  '858': 'Uruguay',
#  '860': 'Uzbekistan',
#  '862': 'Venezuela (Bolivarian Republic of)',
#  '866': 'Viet Nam, Democratic Republic of [former]',
#  '868': 'South Viet-Nam, Republic of [former]',
#  '869': 'World Intellectual Property Organization (WIPO)',
#  '870': 'African Intellectual Property Organization (OAPI)',
#  '871': 'African Regional Intellectual Property Organization (ARIPO)',
#  '872': 'Wake Island [former]',
#  '873': 'World Food Conference (WFC)',
#  '874': 'World Food Programme (WFP)',
#  '875': 'Western Africa not elsewhere specified',
#  '876': 'Wallis and Futuna Islands',
#  '877': 'British West Indies [former]',
#  '878': 'West Indies Associated States',
#  '879': 'Western Asia not elsewhere specified',
#  '880': 'World Health Organization (WHO)',
#  '881': 'Western Europe not elsewhere specified',
#  '882': 'Samoa',
#  '883': 'British Windward Islands [former]',
#  '884': 'Yaounde Treaty States',
#  '885': 'World Meteorological Organization (WMO)',
#  '887': 'Yemen',
#  '720': 'Democratic Yemen [former]',
#  '886': 'Yemen [former]',
#  '888': 'World Bank (WB)',
#  '889': 'World Trade Organization (WTO)',
#  '890': 'Yugoslavia [former]',
#  '891': 'Serbia and Montenegro [former]',
#  '892': 'Economic Community of West African States (ECOWAS)',
#  '894': 'Zambia',
#  '896': 'Areas not elsewhere specified',
#  '898': 'Areas not specified',
#  '899': 'Areas not elsewhere specified and unknown',
#  'AF': 'Afghanistan',
#  'AL': 'Albania',
#  'AQ': 'Antarctica',
#  'DZ': 'Algeria',
#  'AS': 'American Samoa',
#  'AD': 'Andorra',
#  'AO': 'Angola',
#  'AG': 'Antigua and Barbuda',
#  'AZ': 'Azerbaijan',
#  'AR': 'Argentina',
#  'AU': 'Australia',
#  'AT': 'Austria',
#  'BS': 'Bahamas',
#  'BH': 'Bahrain',
#  'BD': 'Bangladesh',
#  'AM': 'Armenia',
#  'BB': 'Barbados',
#  'BE': 'Belgium',
#  'BM': 'Bermuda',
#  'BT': 'Bhutan',
#  'BO': 'Bolivia (Plurinational State of)',
#  'BA': 'Bosnia and Herzegovina',
#  'BW': 'Botswana',
#  'BV': 'Bouvet Island',
#  'BR': 'Brazil',
#  'BZ': 'Belize',
#  'IO': 'British Indian Ocean Territory',
#  'SB': 'Solomon Islands',
#  'VG': 'British Virgin Islands',
#  'BN': 'Brunei Darussalam',
#  'BG': 'Bulgaria',
#  'MM': 'Myanmar',
#  'BI': 'Burundi',
#  'BY': 'Belarus',
#  'KH': 'Cambodia',
#  'CM': 'Cameroon',
#  'CA': 'Canada',
#  'CT': 'Canton and Enderbury Islands [former]',
#  'CV': 'Cabo Verde',
#  'KY': 'Cayman Islands',
#  'CF': 'Central African Republic',
#  'LK': 'Sri Lanka',
#  'TD': 'Chad',
#  'CL': 'Chile',
#  'CN': 'China',
#  'TW': 'Taiwan Province of China',
#  'CX': 'Christmas Island',
#  'CC': 'Cocos (Keeling) Islands',
#  'CO': 'Colombia',
#  'KM': 'Comoros',
#  'YT': 'Mayotte',
#  'CG': 'Congo',
#  'CD': 'Democratic Republic of the Congo',
#  'CK': 'Cook Islands',
#  'CR': 'Costa Rica',
#  'HR': 'Croatia',
#  'CU': 'Cuba',
#  'CY': 'Cyprus',
#  'CS': 'Czechoslovakia [former]',
#  'CZ': 'Czechia',
#  'BJ': 'Benin',
#  'DK': 'Denmark',
#  'DM': 'Dominica',
#  'DO': 'Dominican Republic',
#  'NQ': 'Dronning Maud Land [former]',
#  'EC': 'Ecuador',
#  'SV': 'El Salvador',
#  'GQ': 'Equatorial Guinea',
#  'ET': 'Ethiopia',
#  'ER': 'Eritrea',
#  'EE': 'Estonia',
#  'FO': 'Faroe Islands',
#  'FK': 'Falkland Islands (Malvinas)',
#  'GS': 'South Georgia and the South Sandwich Islands',
#  'FJ': 'Fiji',
#  'FI': 'Finland',
#  'AX': 'Åland Islands',
#  'FX': 'France, Metropolitan [former]',
#  'FR': 'France',
#  'GF': 'French Guiana',
#  'PF': 'French Polynesia',
#  'FQ': 'French Southern Territories',
#  'DJ': 'Djibouti',
#  'GA': 'Gabon',
#  'GE': 'Georgia',
#  'GM': 'Gambia',
#  'PS': 'State of Palestine',
#  'DE': 'Germany',
#  'DD': 'German Democratic Republic [former]',
#  'GH': 'Ghana',
#  'GI': 'Gibraltar',
#  'KI': 'Kiribati',
#  'GR': 'Greece',
#  'GL': 'Greenland',
#  'GD': 'Grenada',
#  'GP': 'Guadeloupe',
#  'GU': 'Guam',
#  'GT': 'Guatemala',
#  'GN': 'Guinea',
#  'GY': 'Guyana',
#  'HT': 'Haiti',
#  'HM': 'Heard Island and McDonald Islands',
#  'VA': 'Holy See',
#  'HN': 'Honduras',
#  'HK': 'China, Hong Kong Special Administrative Region',
#  'HU': 'Hungary',
#  'IS': 'Iceland',
#  'IN': 'India',
#  'ID': 'Indonesia',
#  'IR': 'Iran (Islamic Republic of)',
#  'IQ': 'Iraq',
#  'IE': 'Ireland',
#  'IL': 'Israel',
#  'IT': 'Italy',
#  'CI': 'Côte d’Ivoire',
#  'JM': 'Jamaica',
#  'JP': 'Japan',
#  'JT': 'Johnston Island [former]',
#  'KZ': 'Kazakhstan',
#  'JO': 'Jordan',
#  'KE': 'Kenya',
#  'KP': "Democratic People's Republic of Korea",
#  'KR': 'Republic of Korea',
#  'KW': 'Kuwait',
#  'KG': 'Kyrgyzstan',
#  'LA': "Lao People's Democratic Republic",
#  'LB': 'Lebanon',
#  'LS': 'Lesotho',
#  'LV': 'Latvia',
#  'LR': 'Liberia',
#  'LY': 'Libya',
#  'LI': 'Liechtenstein',
#  'LT': 'Lithuania',
#  'LU': 'Luxembourg',
#  'MO': 'China, Macao Special Administrative Region',
#  'MG': 'Madagascar',
#  'MW': 'Malawi',
#  'MY': 'Malaysia',
#  'MV': 'Maldives',
#  'ML': 'Mali',
#  'MT': 'Malta',
#  'MQ': 'Martinique',
#  'MR': 'Mauritania',
#  'MU': 'Mauritius',
#  'MX': 'Mexico',
#  'MI': 'Midway Islands [former]',
#  'MC': 'Monaco',
#  'MN': 'Mongolia',
#  'MD': 'Republic of Moldova',
#  'ME': 'Montenegro',
#  'MS': 'Montserrat',
#  'MA': 'Morocco',
#  'MZ': 'Mozambique',
#  'OM': 'Oman',
#  'NA': 'Namibia',
#  'NR': 'Nauru',
#  'NP': 'Nepal',
#  'NL': 'Netherlands',
#  'AN': 'Netherlands Antilles [former, 1986 to 2010]',
#  'CW': 'Curaçao',
#  'AW': 'Aruba',
#  'SX': 'Sint Maarten (Dutch part)',
#  'BQ': 'Bonaire, Sint Eustatius and Saba',
#  'NT': 'Neutral Zone (Saudi Arabia and Iraq) [former]',
#  'NC': 'New Caledonia',
#  'VU': 'Vanuatu',
#  'NZ': 'New Zealand',
#  'NI': 'Nicaragua',
#  'NE': 'Niger',
#  'NG': 'Nigeria',
#  'NU': 'Niue',
#  'NF': 'Norfolk Island',
#  'NO': 'Norway',
#  'MP': 'Northern Mariana Islands',
#  'UM': 'United States minor outlying islands',
#  'PC': 'Pacific Islands (Trust Territory) [former]',
#  'FM': 'Micronesia (Federated States of)',
#  'MH': 'Marshall Islands',
#  'PW': 'Palau',
#  'PK': 'Pakistan',
#  'PA': 'Panama',
#  'PZ': 'Panama Canal Zone [former]',
#  'PG': 'Papua New Guinea',
#  'PY': 'Paraguay',
#  'PE': 'Peru',
#  'PH': 'Philippines',
#  'PN': 'Pitcairn',
#  'PL': 'Poland',
#  'PT': 'Portugal',
#  'GW': 'Guinea-Bissau',
#  'TL': 'Timor-Leste',
#  'PR': 'Puerto Rico',
#  'QA': 'Qatar',
#  'RE': 'Réunion',
#  'RO': 'Romania',
#  'RU': 'Russian Federation',
#  'RW': 'Rwanda',
#  'BL': 'Saint Barthélemy',
#  'SH': 'Saint Helena',
#  'KN': 'Saint Kitts and Nevis',
#  'AI': 'Anguilla',
#  'LC': 'Saint Lucia',
#  'MF': 'Saint Martin (French Part)',
#  'PM': 'Saint Pierre and Miquelon',
#  'VC': 'Saint Vincent and the Grenadines',
#  'SM': 'San Marino',
#  'ST': 'Sao Tome and Principe',
#  'SA': 'Saudi Arabia',
#  'SN': 'Senegal',
#  'RS': 'Serbia',
#  'SC': 'Seychelles',
#  'SL': 'Sierra Leone',
#  'SG': 'Singapore',
#  'SK': 'Slovakia',
#  'VN': 'Viet Nam',
#  'SI': 'Slovenia',
#  'SO': 'Somalia',
#  'ZA': 'South Africa',
#  'ZW': 'Zimbabwe',
#  'YD': 'Democratic Yemen [former]',
#  'ES': 'Spain',
#  'SS': 'South Sudan',
#  'SD': 'Sudan',
#  'EH': 'Western Sahara',
#  'SR': 'Suriname',
#  'SJ': 'Svalbard and Jan Mayen Islands',
#  'SZ': 'Eswatini',
#  'SE': 'Sweden',
#  'CH': 'Switzerland',
#  'SY': 'Syrian Arab Republic',
#  'TJ': 'Tajikistan',
#  'TH': 'Thailand',
#  'TG': 'Togo',
#  'TK': 'Tokelau',
#  'TO': 'Tonga',
#  'TT': 'Trinidad and Tobago',
#  'AE': 'United Arab Emirates',
#  'TN': 'Tunisia',
#  'TR': 'Turkey',
#  'TM': 'Turkmenistan',
#  'TC': 'Turks and Caicos Islands',
#  'TV': 'Tuvalu',
#  'UG': 'Uganda',
#  'UA': 'Ukraine',
#  'MK': 'The former Yugoslav Republic of Macedonia',
#  'SU': 'Union of Soviet Socialist Republics [former]',
#  'EG': 'Egypt',
#  'GB': 'United Kingdom of Great Britain and Northern Ireland',
#  'GG': 'Guernsey',
#  'JE': 'Jersey',
#  'IM': 'Isle of Man',
#  'TZ': 'United Republic of Tanzania',
#  'US': 'United States of America',
#  'PU': 'United States miscellaneous Pacific Islands [former]',
#  'VI': 'United States Virgin Islands',
#  'BF': 'Burkina Faso',
#  'UY': 'Uruguay',
#  'UZ': 'Uzbekistan',
#  'VE': 'Venezuela (Bolivarian Republic of)',
#  'VD': 'Viet Nam, Democratic Republic of [former]',
#  'WK': 'Wake Island [former]',
#  'WF': 'Wallis and Futuna Islands',
#  'WS': 'Samoa',
#  'YE': 'Yemen',
#  'YU': 'Serbia and Montenegro [former]',
#  'ZM': 'Zambia',
#  '901': 'More developed regions',
#  '902': 'Less developed regions',
#  '934': 'Less developed regions, excluding least developed countries',
#  '948': 'Less developed regions, excluding China',
#  '1500': 'WB_Low-income countries',
#  '1501': 'WB_Lower-middle-income countries',
#  '1502': 'WB_Upper-middle-income countries',
#  '1503': 'WB_High-income countries',
#  '1517': 'WB_Middle-income countries'}

# %%
import country_converter as coco

# %%
some_names = ['United Rep. of Tanzania', 'DE', 'Cape Verde', '788', 'Burma', 'Burma', 'COG',
              'Iran (Islamic Republic of)', 'Korea, Republic of',
              "Dem. People's Rep. of Korea"]
standard_names = coco.convert(names=some_names, to='iso3')
print(standard_names)
# Out:
# ['TZA', 'DEU', 'CPV', 'TUN', 'MMR', 'MMR', 'COG', 'IRN', 'KOR', 'PRK']
